# %% [markdown]
# ---
# title: Implementing Neural Processes
# date: 2020-02-14
#
# ---

# %% [markdown]
# Why are NPs super cool? They include some probabilistic element, like in Gaussian processes but without the complexity $O(n^3)$, where $n$ is the number of data points. Original paper [here](https://arxiv.org/abs/1807.01622).
#
# Full implementation [here](https://github.com/martagrz/neural-processes)
