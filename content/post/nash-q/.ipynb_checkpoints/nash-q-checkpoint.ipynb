# %% [markdown]
# ---
# title: Implementing Nash-Q Learning
# date: 2020-02-14
#
# ---

# %% [markdown]
# Implementing Q-learning in multi-agent reinforcement learning settings leads to a non-stationary environment for the agents as the environment is constantly changing. On more of this, have a look at [this post](https://martagrz.github.io/project/simultaneous-q/)
